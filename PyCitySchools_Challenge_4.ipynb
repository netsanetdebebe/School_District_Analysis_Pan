# %% [markdown]
# # Importing Data Files

# %%
# import dependencies and set up
import pandas as pd 
import os

# %%
school_data_to_load = "school_complete.csv"
student_data_to_load = "students_complete.csv"

# %%
school_data_df = pd.read_csv(school_data_to_load)
student_data_df = pd.read_csv(student_data_to_load)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 school_data_df = pd.read_csv(school_data_to_load)
#       2 student_data_df = pd.read_csv(student_data_to_load)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
school_data_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
student_data_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %% [markdown]
# Cleaning Data

# %%
student_data_df.count()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# dtype: int64

# %%
#Step 2 is cleaning student namaes and replacing substrings in python 
prefixes_suffixes = ["Dr.", "Ms.", "Mr.", "MD", "PhD", "Mrs.", "Miss", "DDS", "DVM", ]

for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
# Out:
# C:\Users\15417\AppData\Local\Temp\ipykernel_20652\1458914135.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")

# %%
student_data_df.head(25)
# Out:
#     Student ID        student_name gender grade        school_name  \
# 0            0        Paul Bradley      M   9th  Huang High School
# 1            1        Victor Smith      M  12th  Huang High School
# 2            2     Kevin Rodriguez      M  12th  Huang High School
# 3            3       Richard Scott      M  12th  Huang High School
# 4            4          Bonnie Ray      F   9th  Huang High School
# 5            5       Bryan Miranda      M   9th  Huang High School
# 6            6       Sheena Carter      F  11th  Huang High School
# 7            7        Nicole Baker      F  12th  Huang High School
# 8            8        Michael Roth      M  10th  Huang High School
# 9            9      Matthew Greene      M  10th  Huang High School
# 10          10    Andrew Alexander      M  10th  Huang High School
# 11          11       Daniel Cooper      M  10th  Huang High School
# 12          12     Brittney Walker      F   9th  Huang High School
# ...

# %% [markdown]
# # Challenege here is replacing  the reading and maths scores - having difficulty

# %%
Thomas_High_School_student_data_df = student_data_df[(student_data_df["school_name"] == "Thomas High School")
                & (student_data_df["grade"] == "9th")].index 
thomas_high_school_student_data_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [29], in <cell line: 3>()
#       1 Thomas_High_School_student_data_df = student_data_df[(student_data_df["school_name"] == "Thomas High School")
#       2                 & (student_data_df["grade"] == "9th")].index
# ----> 3 thomas_high_school_student_data_df
#
# NameError: name 'thomas_high_school_student_data_df' is not defined

# %%
cleaned_df = student_data_df.drop(thomas_high_school_student_data_df , inplace=False)
cleaned_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 cleaned_df = student_data_df.drop(thomas_high_school_student_data_df , inplace=False)
#       2 cleaned_df
#
# NameError: name 'thomas_high_school_student_data_df' is not defined

# %%
student_data_df.count
# Out:
# <bound method DataFrame.count of        Student ID      student_name gender grade         school_name  \
# 37537       37537       Erik Snyder      M   9th  Thomas High School
# 37538       37538    Tanya Martinez      F   9th  Thomas High School
# 37539       37539     Noah Erickson      M   9th  Thomas High School
# 37540       37540      Austin Meyer      M   9th  Thomas High School
# 37543       37543   Madison Hampton      F   9th  Thomas High School
# ...           ...               ...    ...   ...                 ...
# 39152       39152        Lori Moore      F   9th  Thomas High School
# 39153       39153   William Hubbard      M   9th  Thomas High School
# 39157       39157  Kristen Gonzalez      F   9th  Thomas High School
# 39164       39164    Joseph Anthony      M   9th  Thomas High School
# 39167       39167    Rebecca Tanner      F   9th  Thomas High School
#
#        reading_score  math_score
# 37537             80          90
# 37538             71          69
# ...

# %% [markdown]
# # Replace math and reading scores with NaN for 9th grade at Thomas High

# %%
import numpy as np

# %%
student_data_df.loc[
    (student_data_df["school_name"] == "Thomas High School") & 
    (student_data_df["grade"] == "9th") &
    (student_data_df["reading_scores"] > 0), "reading_score"=np.nan]
# Out:
#   Input In [36]
#     (student_data_df["reading_scores"] > 0), "reading_score"=np.nan]
#                                                             ^
# SyntaxError: invalid syntax

# %%
student_data_df.head(10)
# Out:
#        Student ID     student_name gender grade         school_name  \
# 37537       37537      Erik Snyder      M   9th  Thomas High School
# 37538       37538   Tanya Martinez      F   9th  Thomas High School
# 37539       37539    Noah Erickson      M   9th  Thomas High School
# 37540       37540     Austin Meyer      M   9th  Thomas High School
# 37543       37543  Madison Hampton      F   9th  Thomas High School
# 37550       37550    Patricia Diaz      F   9th  Thomas High School
# 37558       37558  Kelly Henderson      M   9th  Thomas High School
# 37559       37559      Kiara Bates      F   9th  Thomas High School
# 37562       37562     Teresa Johns      F   9th  Thomas High School
# 37564       37564  Stephen Patrick      M   9th  Thomas High School
#
#        reading_score  math_score
# 37537             80          90
# 37538             71          69
# 37539             86          76
# 37540             73          96
# 37543             82          73
# ...

# %%
import numpy as np

# %%
student_data_df.loc[]
# Out:
#   Input In [44]
#     student_data_df.loc[]
#                         ^
# SyntaxError: invalid syntax
